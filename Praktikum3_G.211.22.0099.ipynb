# %%
# Input list
my_list = ['p', 'r', 'o', 'g', 'r', 'a', 'm', 'm', 'i', 'n', 'g']

# Menggabungkan elemen-elemen list menjadi string
result_string = ''.join(my_list)

# Menampilkan output
print("Output:", result_string)
# Out:
# Output: programming
